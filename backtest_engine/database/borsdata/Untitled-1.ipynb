# %%
from borsdata_client import BorsdataClient
client = BorsdataClient()
dfs = client.history_kpi(66,'Large Cap', 'Sverige')
# Out:
# Atlas Copco A
# AAKAstraZeneca
#
# Biotage
# Nordnet
# Intrum
# Kinnevik B
# Addtech
# Autoliv
# Beijer Ref
# Alfa Laval
# ABB
# Fabege
# Millicom
# Bilia
# Hexpol
# Assa Abloy
# Sandvik
# Bure Equity
# SEB A
# Atrium Ljungberg
# Holmen B
# Axfood
# Securitas
# New Wave
# Lagercrantz
# HMS Networks
# Industrivärden C
# Orrön Energy
# Mycronic
# Sagax A
# Addnode
# Catena
# Modern Times Group B
# Avanza Bank
# Sectra
# Diös Fastigheter
# Peab
# Lundbergföretagen
# JM
# Billerud
# Boliden
# Wallenstam
# Volati
# Loomis
# Electrolux B
# Investor B
# Bravida
# Latour
# Fastpartner A
# Thule
# Cint GroupAtlas Copco B
# Fortnox
# Sweco A
#
# Medicover
# Lindab
# Embracer
# Vitec Software
# Instalco
# AFRYHemnet
# Tele2 A
# NP3 Fastigheter Pref
# Trelleborg
#
# Truecaller
# Storskogen
# NCAB Group
# Investor A
# Essity A
# Husqvarna A
# Volvo Car
# Sdiptech Pref
# Traton
# SSAB B
# Husqvarna B
# Epiroc A
# Holmen A
# Skanska
# Creades
# Ratos B
# Kinnevik A
# Kindred
# Sagax B
# ...

# %%
import pandas as pd
frames = pd.concat(dfs)
frames[frames.name == 'Addnode']
# Out:
#     year  period  kpiValue     name
# 0   2013       3     0.563  Addnode
# 1   2013       4     0.563  Addnode
# 2   2014       1     0.563  Addnode
# 3   2014       2     0.563  Addnode
# 4   2014       3     0.563  Addnode
# 5   2014       4     0.563  Addnode
# 6   2015       1     0.563  Addnode
# 7   2015       2     0.563  Addnode
# 8   2015       3     0.563  Addnode
# 9   2015       4     0.563  Addnode
# 10  2016       1     0.563  Addnode
# 11  2016       2     0.563  Addnode
# 12  2016       3     0.563  Addnode
# 13  2016       4     0.563  Addnode
# 14  2017       1     0.563  Addnode
# 15  2017       2     0.563  Addnode
# 16  2017       3     0.563  Addnode
# 17  2017       4     0.563  Addnode
# 18  2018       1     0.563  Addnode
# 19  2018       2     0.563  Addnode
# 20  2018       3     0.563  Addnode
# 21  2018       4     0.625  Addnode
# 22  2019       1     0.625  Addnode
# 23  2019       2     0.625  Addnode
# 24  2019       3     0.625  Addnode
# ...
