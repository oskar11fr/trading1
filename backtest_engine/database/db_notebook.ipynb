# %%
from finance_database_script import finance_database

assets = ['SPY', 'SLV', 'TLT', 'XLE', 'BIL', 'GLD', 'QQQ', 'EEM']
etf_database = finance_database('etf_db')

etf_database.import_to_database(assets)
# Out:
# [*********************100%***********************]  1 of 1 completed
# New table created for SPY with 7748 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for SLV with 4411 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for TLT with 5355 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for XLE with 6258 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for BIL with 4139 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for GLD with 4773 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for QQQ with 6206 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for EEM with 5177 rows

# %%
from finance_database_script import finance_database

assets = ['^VIX', '^VIX3M', 'SVXY', 'BIL']
VIX_database = finance_database('vix_database')

VIX_database.import_to_database(assets)
# Out:
# [*********************100%***********************]  1 of 1 completed
# New table created for _VIX with 8527 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for _VIX3M with 4357 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for SVXY with 3042 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for BIL with 4139 rows

# %%
from finance_database_script import finance_database

assets = ['BTC-USD', 
          'ETH-USD', 
          'XRP-USD', 
          'USDT-USD', 
          'SHIB-USD', 
          'DOGE-USD'
        ]
etf_database = finance_database('crypto_db')

for asset in assets:
  etf_database.sql_importer(asset)
# Out:
# [*********************100%***********************]  1 of 1 completed
# New table created for BTC_USD with 3336 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for ETH_USD with 2187 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for XRP_USD with 2187 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for USDT_USD with 2187 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for SHIB_USD with 933 rows
# [*********************100%***********************]  1 of 1 completed
# New table created for DOGE_USD with 2187 rows

# %%
from borsdata.borsdata_kpi_database_script import kpiDataBase


aktier_se_lc = kpiDataBase(61, 'Large Cap', 'Sverige')
print(aktier_se_lc.engine_name)
aktier_se_lc.create_database()

aktier_no_lc = kpiDataBase(61, 'Oslo Bors', 'Norge')
print(aktier_no_lc.engine_name)
aktier_no_lc.create_database()

aktier_dk_lc = kpiDataBase(61, 'Large Cap', 'Danmark')
print(aktier_dk_lc.engine_name)
aktier_dk_lc.create_database()

# %%
from borsdata.borsdata_kpi_database_script import kpiDataBase


aktier_se_mc = kpiDataBase(61, 'Mid Cap', 'Sverige')
print(aktier_se_mc.engine_name)
aktier_se_mc.create_database()

aktier_no_mc = kpiDataBase(61, 'Oslo Expand', 'Norge')
print(aktier_no_mc.engine_name)
aktier_no_mc.create_database()

aktier_dk_mc = kpiDataBase(61, 'Mid Cap', 'Danmark')
print(aktier_dk_mc.engine_name)
aktier_dk_mc.create_database()

# %%
from borsdata.borsdata_kpi_database_script import kpiDataBase


aktier_se_sc = kpiDataBase(61, 'Small Cap', 'Sverige')
print(aktier_se_sc.engine_name)
aktier_se_sc.create_database()

aktier_no_sc = kpiDataBase(61, 'Oslo Growth', 'Norge')
print(aktier_no_sc.engine_name)
aktier_no_sc.create_database()

aktier_dk_sc = kpiDataBase(61, 'Small Cap', 'Danmark')
print(aktier_dk_sc.engine_name)
aktier_dk_sc.create_database()
# Out:
# AntalAktier_Small_Cap_Sverige
# Bong Ljungdahl
# Anoto
# Nelly Group
# Björn Borg
# Bergs Timber
# Active Biotech
# BE Group
# Elon
# Midsona B
# TradeDoubler
# Doro
# Strax
# Svedbergs
# Concordia Maritime
# PION Group
# Prevas
# Micro Systemation
# NAXS
# C-RAD
# Vivesto
# Image Systems
# Railcare
# Senzime
# Moment Group
# Formpipe Software
# Medivir
# Karolinska Development
# Duroc
# Lammhults Design
# Eniro
# ProfilGruppen
# Precise Biometrics
# Orexo
# Saniona
# SinterCast
# Midway B
# Oscar Properties
# Rizzo Group
# Christian Berner Tech
# Mendus
# Dedicare
# Novotek
# Havsfrun Investment
# Starbreeze B
# NGS Group
# Oscar Properties Pref
# Wise Group
# Boule Diagnostics
# Concejo B
# Studsvik
# Empir Group
# Sensys Gatso
# Stockwik Förvaltning
# Abliva
# Ortivus B
# Ortivus A
# Malmbergs Elektriska
# Acrinova A
# Softronic
# Egetis Therapeutics
# Moberg Pharma
# Arla Plast
# Episurf Medical
# IRRAS
# Nilörngruppen
# Readly
# Q-Linea
# Projektengagemang
# Immunovia
# Isofol MedicalHanza
# CoinShares
# Infrea
#
# Sleep Cycle
# Seafire
# Acrinova B
# Qliro
# Solid Försäkring
# Oncopeptides
# B3 Consulting
# Ferronordic
# Cantargia
# Nanologica
# Oscar Properties Pref B
# Ascelia Pharma
# Infant Bacterial
# Maha Energy
# Transtema
# Xspray Pharma
# Midsona A
# Pierce Group
# Vicore Pharma
# Midway A
# Actic Group
# Alligator Bioscience
# Starbreeze A
# Imported Bong_Ljungdahl
# Imported Anoto
# Imported Nelly_Group
# Imported Björn_Borg
# Imported Bergs_Timber
# Imported Active_Biotech
# Imported BE_Group
# Imported Elon
# Imported Midsona_B
# Imported TradeDoubler
# Imported Doro
# Imported Strax
# Imported Svedbergs
# Imported Concordia_Maritime
# Imported PION_Group
# Imported Prevas
# Imported Micro_Systemation
# Imported NAXS
# Imported C_RAD
# Imported Vivesto
# Imported Image_Systems
# Imported Railcare
# Imported Senzime
# Imported Moment_Group
# Imported Formpipe_Software
# Imported Medivir
# Imported Karolinska_Development
# Imported Duroc
# Imported Lammhults_Design
# Imported Eniro
# Imported ProfilGruppen
# Imported Precise_Biometrics
# Imported Orexo
# Imported Saniona
# Imported SinterCast
# Imported Midway_B
# Imported Oscar_Properties
# Imported Rizzo_Group
# Imported Christian_Berner_Tech
# Imported Mendus
# Imported Dedicare
# Imported Novotek
# Imported Havsfrun_Investment
# Imported Starbreeze_B
# Imported NGS_Group
# Skipped Oscar_Properties_Pref
# Imported Wise_Group
# Imported Boule_Diagnostics
# Imported Concejo_B
# Imported Studsvik
# Imported Empir_Group
# Imported Sensys_Gatso
# Imported Stockwik_Förvaltning
# Imported Abliva
# Imported Ortivus_B
# Imported Ortivus_A
# Imported Malmbergs_Elektriska
# Imported Acrinova_A
# Imported Softronic
# Imported Egetis_Therapeutics
# Imported Moberg_Pharma
# Imported Arla_Plast
# Imported Episurf_Medical
# Imported IRRAS
# Imported Nilörngruppen
# Imported Readly
# Imported Q_Linea
# Imported Projektengagemang
# Imported Immunovia
# Imported Hanza
# Imported CoinShares
# Imported Infrea
# Imported Isofol_Medical
# Imported Sleep_Cycle
# Imported Seafire
# Imported Acrinova_B
# Imported Qliro
# Imported Solid_Försäkring
# Imported Oncopeptides
# Imported B3_Consulting
# Imported Ferronordic
# Imported Cantargia
# Imported Nanologica
# Skipped Oscar_Properties_Pref_B
# Imported Ascelia_Pharma
# Imported Infant_Bacterial
# Imported Maha_Energy
# Imported Transtema
# Imported Xspray_Pharma
# Imported Midsona_A
# Imported Pierce_Group
# Imported Vicore_Pharma
# Imported Midway_A
# Imported Actic_Group
# Imported Alligator_Bioscience
# Imported Starbreeze_A
# AntalAktier_Oslo_Growth_Norge
# Awilco DrillingInduct
# Grong Sparebank
#
# SoftOx Solutions
# Black Sea Property
# Sunndal Sparebank
# River Tech
# Aasen Sparebank
# BW Epic Kosan
# Lea Bank
# Tysnes Sparebank
# Golden Energy Offshore
# Huddlestock Fintech
# Lumi Gruppen
# Mintra
# Lifecare
# ININ Group
# Elektroimportoren
# Proximar Seafood
# Zwipe
# Clean Seas Seafood
# TECO 2030
# Andfjord Salmon
# Everfuel
# MPC Energy Solutions
# Green Minerals
# Horisont Energi
# Instabank
# Desert Control
# Kyoto Group
# Cambi
# EXACT Therapeutics
# CodeLab Capital
# Huddly
# BW Ideol
# The Kingfish Company
# Ayfie
# Spotlio
# Baltic Sea Properties
# Zenith Energy
# Icelandic Salmon
# Harmonychain
# Pryme
# Quantafuel
# Statt Torsk
# Romerike Sparebank
# Romsdal Sparebank
# Xplora Technologies
# Recreate
# Norsk Solar
# Cyviz
# Nordic Unmanned
# Kraft Bank
# Måsoval
# Envipco
# Hav Group
# Nidaros Sparebank
# Nordic Halibut
# Hynion
# Circa Group
# M Vest Water
# Nordic Aqua Partners
# Integrated Wind
# Lytix Biopharma
# Ice Fish Farm
# Skandia GreenPower
# Norsk Titanium
# Bergen Carbon
# Arctic Bioscience
# ADS Maritime
# Argeo
# Deep Value Driller
# Norcod
# Smartoptics
# Ocean Sun
# CSAM Health
# ECIT
# Arctic Fish
# Nordhealth
# Gigante Salmon
# Alternus Energy
# Vow Green Metals
# Barramundi
# Questback
# Sparebank 68 grader nord
# Akobo Minerals
# Havila Kystruten
# Astrocast
# Norwegian Block Exchange
# BioFish
# Western Bulk Chartering
# Stainless Tankers
# Pyrum Innovations
# Standard Supply
# Ocean GeoLoop
# Energeia
# Shelf Drilling North Sea
# Benchmark Holdings
# Aurora Eiendom
# ReFuels N.V.Hyon
#
# Inify Laboratories
# Capsol Technologies
# Cool Company
# Nordic Technology
# WPU - Waste Plastic Upcycling
# Noram Drilling
# Dolphin Drilling
# Imported Induct
# Imported Grong_Sparebank
# Imported Awilco_Drilling
# Imported SoftOx_Solutions
# Imported Black_Sea_Property
# Imported Sunndal_Sparebank
# Imported River_Tech
# Imported Aasen_Sparebank
# Imported BW_Epic_Kosan
# Imported Lea_Bank
# Imported Tysnes_Sparebank
# Imported Golden_Energy_Offshore
# Imported Huddlestock_Fintech
# Imported Lumi_Gruppen
# Imported Mintra
# Imported Lifecare
# Imported ININ_Group
# Imported Elektroimportoren
# Imported Proximar_Seafood
# Imported Zwipe
# Imported Clean_Seas_Seafood
# Imported TECO_2030
# Imported Andfjord_Salmon
# Imported Everfuel
# Imported MPC_Energy_Solutions
# Imported Green_Minerals
# Imported Horisont_Energi
# Imported Instabank
# Imported Desert_Control
# Imported Kyoto_Group
# Imported Cambi
# Imported EXACT_Therapeutics
# Imported CodeLab_Capital
# Imported Huddly
# Imported BW_Ideol
# Imported The_Kingfish_Company
# Imported Ayfie
# Imported Spotlio
# Imported Baltic_Sea_Properties
# Imported Zenith_Energy
# Imported Icelandic_Salmon
# Imported Harmonychain
# Imported Pryme
# Imported Quantafuel
# Imported Statt_Torsk
# Imported Romerike_Sparebank
# Imported Romsdal_Sparebank
# Imported Xplora_Technologies
# Imported Recreate
# Imported Norsk_Solar
# Imported Cyviz
# Imported Nordic_Unmanned
# Imported Kraft_Bank
# Imported Måsoval
# Imported Envipco
# Imported Hav_Group
# Imported Nidaros_Sparebank
# Imported Nordic_Halibut
# Imported Hynion
# Imported Circa_Group
# Imported M_Vest_Water
# Imported Nordic_Aqua_Partners
# Imported Integrated_Wind
# Imported Lytix_Biopharma
# Imported Ice_Fish_Farm
# Imported Skandia_GreenPower
# Imported Norsk_Titanium
# Imported Bergen_Carbon
# Imported Arctic_Bioscience
# Imported ADS_Maritime
# Imported Argeo
# Imported Deep_Value_Driller
# Imported Norcod
# Imported Smartoptics
# Imported Ocean_Sun
# Imported CSAM_Health
# Imported ECIT
# Imported Arctic_Fish
# Imported Nordhealth
# Imported Gigante_Salmon
# Imported Alternus_Energy
# Imported Vow_Green_Metals
# Imported Barramundi
# Imported Questback
# Imported Sparebank_68_grader_nord
# Imported Akobo_Minerals
# Imported Havila_Kystruten
# Imported Astrocast
# Skipped Norwegian_Block_Exchange
# Imported BioFish
# Imported Western_Bulk_Chartering
# Skipped Stainless_Tankers
# Imported Pyrum_Innovations
# Imported Standard_Supply
# Imported Ocean_GeoLoop
# Imported Energeia
# Skipped Shelf_Drilling_North_Sea
# Skipped Benchmark_Holdings
# Imported Aurora_Eiendom
# Imported Hyon
# Skipped ReFuels_NV
# Imported Inify_Laboratories
# Imported Capsol_Technologies
# Imported Cool_Company
# Skipped Nordic_Technology
# Imported WPU___Waste_Plastic_Upcycling
# Imported Noram_Drilling
# Imported Dolphin_Drilling
# AntalAktier_Small_Cap_Danmark
# Brondbyernes IFRoblon
# Atlantic Petroleum
# BioPorto
#
# FirstFarms
# Aalborg Boldspilklub
# AGF B
# Brd. Klee
# Scandinavian Brake
# InterMailPenneo
# NewCap Holding
#
# NTR Holding
# Copenhagen Capital
# Pharma Equity
# Fast Ejendom
# Djurslands Bank
# SKAKO
# Nordic Shipholding
# Lollands Bank
# PARKEN Sport
# Rias
# Prime Office
# Fynske Bank
# GreenMobility
# Mons Bank
# Harboes Bryggeri
# Agat Ejendomme
# EAC Invest
# Grönlandsbanken
# Copenhagen Capital Praef
# Cemat
# Strategic Investments
# Nordfyns Bank
# Orphazyme
# Luxor
# German High Street
# Ennogie Solar
# Skjern Bank
# Park Street
# Silkeborg IF
# Hvidbjerg Bank
# Dantax
# Scandinavian Investment
# Kreditbanken
# Glunz & Jensen
# Rovsing
# Imported Roblon
# Imported Atlantic_Petroleum
# Imported BioPorto
# Imported Brondbyernes_IF
# Imported FirstFarms
# Imported Aalborg_Boldspilklub
# Imported AGF_B
# Imported Brd_Klee
# Imported Scandinavian_Brake
# Imported Penneo
# Imported NewCap_Holding
# Imported InterMail
# Imported NTR_Holding
# Imported Copenhagen_Capital
# Imported Pharma_Equity
# Imported Fast_Ejendom
# Imported Djurslands_Bank
# Imported SKAKO
# Imported Nordic_Shipholding
# Imported Lollands_Bank
# Imported PARKEN_Sport
# Imported Rias
# Imported Prime_Office
# Imported Fynske_Bank
# Imported GreenMobility
# Imported Mons_Bank
# Imported Harboes_Bryggeri
# Imported Agat_Ejendomme
# Imported EAC_Invest
# Imported Grönlandsbanken
# Skipped Copenhagen_Capital_Praef
# Imported Cemat
# Imported Strategic_Investments
# Imported Nordfyns_Bank
# Imported Orphazyme
# Imported Luxor
# Imported German_High_Street
# Imported Ennogie_Solar
# Imported Skjern_Bank
# Imported Park_Street
# Imported Silkeborg_IF
# Imported Hvidbjerg_Bank
# Imported Dantax
# Imported Scandinavian_Investment
# Imported Kreditbanken
# Imported Glunz_and_Jensen
# Imported Rovsing

# %%
from borsdata.borsdata_kpi_database_script import kpiDataBase


ord_utd_se_lc = kpiDataBase(66, 'Large Cap', 'Sverige')
print(ord_utd_se_lc.engine_name)
ord_utd_se_lc.create_database()

ord_utd_dk_lc = kpiDataBase(66, 'Large Cap', 'Danmark')
print(ord_utd_dk_lc.engine_name)
ord_utd_dk_lc.create_database()

ord_utd_no_lc = kpiDataBase(66, 'Oslo Bors', 'Norge')
print(ord_utd_no_lc.engine_name)
ord_utd_no_lc.create_database()
# Out:
# OrdinarUtdelning_Large_Cap_Sverige
# Addtech
# Addnode
# AAK
# Investor B
# ABB
# Alfa Laval
# Atlas Copco A
# Corem Property A
# Catena
# Elekta
# Axfood
# LagercrantzAssa Abloy
#
# Atrium Ljungberg
# SinchBoliden
#
# Husqvarna B
# Viaplay BMedicover
# Telia Company
#
# AddLife
# Diös Fastigheter
# SCA A
# Bilia
# Cint Group
# Sagax D
# Sectra
# Wallenstam
# Electrolux Professional BHandelsbanken B
# Nyfosa
# Thule
# NIBE Industrier
# Instalco
# Fastpartner D
# Skanska
# Ericsson A
# Volati Pref
# BioArctic
# Holmen A
# Nordea Bank
#
# Mips
# Kinnevik A
# Trelleborg
# Latour
# Corem Property Pref
# Corem Property B
# Epiroc A
# Fast Balder
# NCAB Group
# NP3 Fastigheter Pref
# Arion Banki
# Nokia
# JM
# Volvo B
# Sampo
# Industrivärden A
# SEB C
# Orrön Energy
# Volvo Car
# Troax Group
# Tele2 A
# Beijer Ref
# Vitec Software
# Sdiptech Pref
# Hexagon
# Bufab
# Epiroc B
# NCC A
# Securitas
# Creades
# Wihlborgs Fastigheter
# Electrolux A
# Boozt
# Intrum
# Atlas Copco B
# Essity A
# AstraZeneca
# Dometic
# SKF B
# Byggfakta
# Pandox
# Lifco
# Volati
# Hexatronic
# Hemnet
# OX2
# New Wave
# Sweco B
# Nolato
# Fabege
# Vitrolife
# Ratos A
# Kindred
# Lundin Mining
# Sagax B
# Sweco A
# Lindab
# Handelsbanken A
# Electrolux B
# Samhällsbyggnadsbolag B
# Industrivärden C
# Peab
# Stora Enso A
# Autoliv
# Hennes & Mauritz
# Fortnox
# NP3 Fastigheter
# Essity B
# Kinnevik B
# SSAB A
# TietoEVRY
# Samhällsbyggnadsbolag D
# Bure Equity
# Ratos B
# Swedish Orphan Biovitrum
# Embracer
# Alleima
# Billerud
# AFRY
# Munters
# Viaplay A
# Systemair
# Holmen B
# Platzer Fastigheter
# Lundin Gold
# International Petroleum
# SCA B
# Storskogen
# Sdiptech
# Swedbank
# Ericsson B
# EQT
# Modern Times Group B
# Investor A
# SSAB B
# Hexpol
# Indutrade
# Sagax A
# Arjo
# Castellum
# Millicom
# NCC B
# Biotage
# Modern Times Group A
# Avanza Bank
# Truecaller
# Lundbergföretagen
# Getinge
# SKF A
# Stillfront
# Volvo A
# Traton
# Husqvarna A
# Nordnet
# Evolution
# Corem Property D
# SEB A
# Hufvudstaden A
# Mycronic
# Bravida
# Stora Enso R
# HMS Networks
# Fenix Outdoor
# Fastpartner A
# Loomis
# Tele2 B
# Sandvik
# Saab
# Imported Addtech
# Imported Addnode
# Imported AAK
# Imported Investor_B
# Imported ABB
# Imported Alfa_Laval
# Imported Atlas_Copco_A
# Imported Corem_Property_A
# Imported Catena
# Imported Elekta
# Imported Axfood
# Imported Assa_Abloy
# Imported Lagercrantz
# Imported Atrium_Ljungberg
# Imported Boliden
# Imported Sinch
# Imported Husqvarna_B
# Imported Medicover
# Imported Telia_Company
# Imported Viaplay_B
# Imported AddLife
# Imported Diös_Fastigheter
# Imported SCA_A
# Imported Bilia
# Imported Cint_Group
# Imported Sagax_D
# Imported Sectra
# Imported Wallenstam
# Imported Handelsbanken_B
# Imported Nyfosa
# Imported Thule
# Imported NIBE_Industrier
# Imported Instalco
# Imported Fastpartner_D
# Imported Skanska
# Imported Ericsson_A
# Imported Volati_Pref
# Imported BioArctic
# Imported Holmen_A
# Imported Nordea_Bank
# Imported Electrolux_Professional_B
# Imported Mips
# Imported Kinnevik_A
# Imported Trelleborg
# Imported Latour
# Imported Corem_Property_Pref
# Imported Corem_Property_B
# Imported Epiroc_A
# Imported Fast_Balder
# Imported NCAB_Group
# Imported NP3_Fastigheter_Pref
# Imported Arion_Banki
# Imported Nokia
# Imported JM
# Imported Volvo_B
# Imported Sampo
# Imported Industrivärden_A
# Imported SEB_C
# Imported Orrön_Energy
# Imported Volvo_Car
# Imported Troax_Group
# Imported Tele2_A
# Imported Beijer_Ref
# Imported Vitec_Software
# Imported Sdiptech_Pref
# Imported Hexagon
# Imported Bufab
# Imported Epiroc_B
# Imported NCC_A
# Imported Securitas
# Imported Creades
# Imported Wihlborgs_Fastigheter
# Imported Electrolux_A
# Imported Boozt
# Imported Intrum
# Imported Atlas_Copco_B
# Imported Essity_A
# Imported AstraZeneca
# Imported Dometic
# Imported SKF_B
# Imported Byggfakta
# Imported Pandox
# Imported Lifco
# Imported Volati
# Imported Hexatronic
# Imported Hemnet
# Imported OX2
# Imported New_Wave
# Imported Sweco_B
# Imported Nolato
# Imported Fabege
# Imported Vitrolife
# Imported Ratos_A
# Imported Kindred
# Imported Lundin_Mining
# Imported Sagax_B
# Imported Sweco_A
# Imported Lindab
# Imported Handelsbanken_A
# Imported Electrolux_B
# Imported Samhällsbyggnadsbolag_B
# Imported Industrivärden_C
# Imported Peab
# Imported Stora_Enso_A
# Imported Autoliv
# Imported Hennes_and_Mauritz
# Imported Fortnox
# Imported NP3_Fastigheter
# Imported Essity_B
# Imported Kinnevik_B
# Imported SSAB_A
# Imported TietoEVRY
# Imported Samhällsbyggnadsbolag_D
# Imported Bure_Equity
# Imported Ratos_B
# Imported Swedish_Orphan_Biovitrum
# Imported Embracer
# Imported Alleima
# Imported Billerud
# Imported AFRY
# Imported Munters
# Imported Viaplay_A
# Imported Systemair
# Imported Holmen_B
# Imported Platzer_Fastigheter
# Imported Lundin_Gold
# Imported International_Petroleum
# Imported SCA_B
# Imported Storskogen
# Imported Sdiptech
# Imported Swedbank
# Imported Ericsson_B
# Imported EQT
# Imported Modern_Times_Group_B
# Imported Investor_A
# Imported SSAB_B
# Imported Hexpol
# Imported Indutrade
# Imported Sagax_A
# Imported Arjo
# Imported Castellum
# Imported Millicom
# Imported NCC_B
# Imported Biotage
# Imported Modern_Times_Group_A
# Imported Avanza_Bank
# Imported Truecaller
# Imported Lundbergföretagen
# Imported Getinge
# Imported SKF_A
# Imported Stillfront
# Imported Volvo_A
# Imported Traton
# Imported Husqvarna_A
# Imported Nordnet
# Imported Evolution
# Imported Corem_Property_D
# Imported SEB_A
# Imported Hufvudstaden_A
# Imported Mycronic
# Imported Bravida
# Imported Stora_Enso_R
# Imported HMS_Networks
# Imported Fenix_Outdoor
# Imported Fastpartner_A
# Imported Loomis
# Imported Tele2_B
# Imported Sandvik
# Imported Saab
# OrdinarUtdelning_Large_Cap_Danmark
# Danske Bank
# Carlsberg B
# GN Store Nord
# DSV
# A.P. Moller Maersk B
# FLSmidth & Co.
# Royal UNIBREW
# Chr Hansen
# Genmab
# Novo Nordisk
# Vestas Wind Systems
# H. Lundbeck B
# Pandora
# NKT Holding
# Coloplast
# Spar Nord Bank
# Scandinavian TobaccoRockwool B
#
# A.P. Moller Maersk A
# Ambu
# Ringkjobing Landbobank
# Alm. Brand
# Boozt
# Noble Corporation
# Zealand Pharma
# Carlsberg A
# ALK-Abello
# Topdanmark
# TORM
# Sydbank
# Bavarian Nordic
# Orsted
# Demant
# ChemoMetecKobenhavns Lufthavne
#
# DFDS
# Rockwool A
# Nordea Bank
# Novozymes
# ISS
# Schouw & Co.
# Össur
# Netcompany Group
# SimCorp
# H. Lundbeck A
# NTG Nordic Transport
# Jyske Bank
# D/S Norden
# Jeudan
# Tryg
# Imported Danske_Bank
# Imported Carlsberg_B
# Imported GN_Store_Nord
# Imported DSV
# Imported AP_Moller_Maersk_B
# Imported FLSmidth_and_Co
# Imported Royal_UNIBREW
# Imported Chr_Hansen
# Imported Genmab
# Imported Novo_Nordisk
# Imported Vestas_Wind_Systems
# Imported H_Lundbeck_B
# Imported Pandora
# Imported NKT_Holding
# Imported Coloplast
# Imported Spar_Nord_Bank
# Imported Rockwool_B
# Imported Scandinavian_Tobacco
# Imported AP_Moller_Maersk_A
# Imported Ambu
# Imported Ringkjobing_Landbobank
# Imported Alm_Brand
# Imported Boozt
# Imported Noble_Corporation
# Imported Zealand_Pharma
# Imported Carlsberg_A
# Imported ALK_Abello
# Imported Topdanmark
# Imported TORM
# Imported Sydbank
# Imported Bavarian_Nordic
# Imported Orsted
# Imported Demant
# Imported Kobenhavns_Lufthavne
# Imported ChemoMetec
# Imported DFDS
# Imported Rockwool_A
# Imported Nordea_Bank
# Imported Novozymes
# Imported ISS
# Imported Schouw_and_Co
# Imported Össur
# Imported Netcompany_Group
# Imported SimCorp
# Imported H_Lundbeck_A
# Imported NTG_Nordic_Transport
# Imported Jyske_Bank
# Imported D/S_Norden
# Imported Jeudan
# Imported Tryg
# OrdinarUtdelning_Oslo_Bors_Norge
# DNO
# Aker BP
# Nordic Semiconductor
# Leroy SeafoodDNB Bank
#
# Autostore
# Sparebanken Vest
# Sikri Group
# Voss Veksel Landmandsbank
# XXL
# Vår Energi
# NEXT Biometrics
# Klaveness Combination
# Aurskog Sparebank
# Electromagnetic Geoservices
# Northern Ocean
# Sparebanken Ost
# Salmon Evolution
# Protector
# Odfjell Technology
# Agilyx
# BEWi
# Sparebanken Sor
# Norwegian Air Shuttle
# Rana Gruber
# Airthings
# Thor Medical
# InterOil Exploration
# SATS
# Pareto Bank
# Elopak
# Aker BioMarine
# Aker Solutions
# Asetek
# Atea
# Gyldendal
# DOF Group
# Tomra Systems
# Sparebank 1 Nord-Norge
# Komplett
# Webstep
# Saga Pure
# Equinor
# StrongPoint
# AF Gruppen
# Aker Horizons
# PCI Biotech
# SmartCraft
# Vistin Pharma
# BW Energy Limited
# Frontline
# Veidekke
# SeaBird Exploration
# Siem Offshore
# Sparebank 1 Nordmore
# Sparebank 1 SMN
# Borr Drilling
# FLEX LNG
# Zaptec
# Itera
# Cloudberry Clean Energy
# Photocure
# REC Silicon
# Bonheur
# Arendals Fossekompani
# Ultimovacs
# BW LPGMPC Container Ships
# Adevinta
# Bien Sparebank
#
# Morrow Bank
# Avance Gas
# Schibsted B
# Olav Thon
# Scatec
# Odfjell Drilling
# NRC Group
# Link Mobility
# Norske Skog
# Europris
# Treasure
# Circio
# Carasent
# Hexagon Purus
# Goodtech
# Elmera
# Havila Shipping
# Eidesvik Offshore
# Elliptic Laboratories
# Gentian Diagnostics
# ArcticZymes
# Sandnes Sparebank
# Nekkar
# Totens Sparebank
# Kongsberg Gruppen
# Odfjell A
# Q-Free
# Atlantic Sapphire
# Holand Og Setskog Sparebank
# Multiconsult
# Reach Subsea
# Edda Wind
# Aker Carbon Capture
# Sparebank 1 Helgeland
# Axactor
# Jaeren Sparebank
# Sparebank 1 Ringerike Hadeland
# Crayon Group
# S.D. Standard ETC
# Hofseth BioCare
# OKEA
# Golden Ocean
# Sparebank 1 Ostlandet
# Sparebank 1 Ostfold Akershus
# Oceanteam
# B2Holding
# Belships
# Austevoll Seafood
# Northern Drilling
# Stolt-Nielsen
# Grieg Seafood
# Gram Car Carriers
# AKVA Group
# Telenor
# Melhus Sparebank
# Orkla
# 2020 Bulkers
# SAS
# Ensurge Micropower
# SalMar
# Bluenord
# Solstad Offshore
# ABL Group
# Byggma
# Gjensidige Forsikring
# EQVA
# BerGenBio
# Nykode Therapeutics
# Kongsberg Automotive
# Volue
# Panoro Energy
# Bouvet
# PetroNor E&P
# Odfjell B
# Yara International
# Techstep
# Okeanis Eco Tankers
# Mowi
# Akastor
# Cadeler
# Kitron
# SpareBank 1 SR-Bank
# Wilh. Wilhelmsen A
# Elkem
# Salmones Camanchaca
# TietoEVRY
# Magnora
# Napatech
# Endur
# Wilh. Wilhelmsen B
# Entra
# Kahoot!
# Norsk Hydro
# Gaming Innovation
# Skue Sparebank
# BW Offshore Limited
# Froy
# Borgestad
# HydrogenPro
# Schibsted A
# Tekna Holding
# Aker
# Hafnia Limited
# Medistim
# Archer
# Scana
# Navamedic
# Petrolia
# Bakkafrost
# ABG Sundal Collier
# Zalaris
# Self Storage
# Borregaard
# TGS
# AMSC
# NEL
# Hexagon Composites
# PGS
# Subsea7
# Pexip
# Kid
# Shelf Drilling
# Norbit
# Sparebanken More
# Höegh Autoliners
# Questerre Energy
# Univid
# Arribatec
# Seadrill
# Sparebank 1 Sorost-Norge
# Prosafe
# Storebrand
# Jinhui Shipping
# Otello
# ContextVision
# poLight
# Vow
# Otovo
# Wallenius Wilhelmsen
# KMC Properties
# Selvaag Bolig
# Polaris Media
# Sogn Sparebank
# IDEX Biometrics
# GC Rieber Shipping
# Imported DNO
# Imported Aker_BP
# Imported Nordic_Semiconductor
# Imported DNB_Bank
# Imported Leroy_Seafood
# Imported Autostore
# Imported Sparebanken_Vest
# Imported Sikri_Group
# Imported Voss_Veksel_Landmandsbank
# Imported XXL
# Imported Vår_Energi
# Imported NEXT_Biometrics
# Imported Klaveness_Combination
# Imported Aurskog_Sparebank
# Imported Electromagnetic_Geoservices
# Imported Northern_Ocean
# Imported Sparebanken_Ost
# Imported Salmon_Evolution
# Imported Protector
# Imported Odfjell_Technology
# Imported Agilyx
# Imported BEWi
# Imported Sparebanken_Sor
# Imported Norwegian_Air_Shuttle
# Imported Rana_Gruber
# Imported Airthings
# Imported Thor_Medical
# Imported InterOil_Exploration
# Imported SATS
# Imported Pareto_Bank
# Imported Elopak
# Imported Aker_BioMarine
# Imported Aker_Solutions
# Imported Asetek
# Imported Atea
# Imported Gyldendal
# Imported DOF_Group
# Imported Tomra_Systems
# Imported Sparebank_1_Nord_Norge
# Imported Komplett
# Imported Webstep
# Imported Saga_Pure
# Imported Equinor
# Imported StrongPoint
# Imported AF_Gruppen
# Imported Aker_Horizons
# Imported PCI_Biotech
# Imported SmartCraft
# Imported Vistin_Pharma
# Imported BW_Energy_Limited
# Imported Frontline
# Imported Veidekke
# Imported SeaBird_Exploration
# Imported Siem_Offshore
# Imported Sparebank_1_Nordmore
# Imported Sparebank_1_SMN
# Imported Borr_Drilling
# Imported FLEX_LNG
# Imported Zaptec
# Imported Itera
# Imported Cloudberry_Clean_Energy
# Imported Photocure
# Imported REC_Silicon
# Imported Bonheur
# Imported Arendals_Fossekompani
# Imported Ultimovacs
# Imported MPC_Container_Ships
# Imported Adevinta
# Imported Bien_Sparebank
# Imported BW_LPG
# Imported Morrow_Bank
# Imported Avance_Gas
# Imported Schibsted_B
# Imported Olav_Thon
# Imported Scatec
# Imported Odfjell_Drilling
# Imported NRC_Group
# Imported Link_Mobility
# Imported Norske_Skog
# Imported Europris
# Imported Treasure
# Imported Circio
# Imported Carasent
# Imported Hexagon_Purus
# Imported Goodtech
# Imported Elmera
# Imported Havila_Shipping
# Imported Eidesvik_Offshore
# Imported Elliptic_Laboratories
# Imported Gentian_Diagnostics
# Imported ArcticZymes
# Imported Sandnes_Sparebank
# Imported Nekkar
# Imported Totens_Sparebank
# Imported Kongsberg_Gruppen
# Imported Odfjell_A
# Imported Q_Free
# Imported Atlantic_Sapphire
# Imported Holand_Og_Setskog_Sparebank
# Imported Multiconsult
# Imported Reach_Subsea
# Imported Edda_Wind
# Imported Aker_Carbon_Capture
# Imported Sparebank_1_Helgeland
# Imported Axactor
# Imported Jaeren_Sparebank
# Imported Sparebank_1_Ringerike_Hadeland
# Imported Crayon_Group
# Imported SD_Standard_ETC
# Imported Hofseth_BioCare
# Imported OKEA
# Imported Golden_Ocean
# Imported Sparebank_1_Ostlandet
# Imported Sparebank_1_Ostfold_Akershus
# Imported Oceanteam
# Imported B2Holding
# Imported Belships
# Imported Austevoll_Seafood
# Imported Northern_Drilling
# Imported Stolt_Nielsen
# Imported Grieg_Seafood
# Imported Gram_Car_Carriers
# Imported AKVA_Group
# Imported Telenor
# Imported Melhus_Sparebank
# Imported Orkla
# Imported 2020_Bulkers
# Imported SAS
# Imported Ensurge_Micropower
# Imported SalMar
# Imported Bluenord
# Imported Solstad_Offshore
# Imported ABL_Group
# Imported Byggma
# Imported Gjensidige_Forsikring
# Imported EQVA
# Imported BerGenBio
# Imported Nykode_Therapeutics
# Imported Kongsberg_Automotive
# Imported Volue
# Imported Panoro_Energy
# Imported Bouvet
# Imported PetroNor_EandP
# Imported Odfjell_B
# Imported Yara_International
# Imported Techstep
# Imported Okeanis_Eco_Tankers
# Imported Mowi
# Imported Akastor
# Imported Cadeler
# Imported Kitron
# Imported SpareBank_1_SR_Bank
# Imported Wilh_Wilhelmsen_A
# Imported Elkem
# Imported Salmones_Camanchaca
# Imported TietoEVRY
# Imported Magnora
# Imported Napatech
# Imported Endur
# Imported Wilh_Wilhelmsen_B
# Imported Entra
# Imported Kahoot!
# Imported Norsk_Hydro
# Imported Gaming_Innovation
# Imported Skue_Sparebank
# Imported BW_Offshore_Limited
# Imported Froy
# Imported Borgestad
# Imported HydrogenPro
# Imported Schibsted_A
# Imported Tekna_Holding
# Imported Aker
# Imported Hafnia_Limited
# Imported Medistim
# Imported Archer
# Imported Scana
# Imported Navamedic
# Imported Petrolia
# Imported Bakkafrost
# Imported ABG_Sundal_Collier
# Imported Zalaris
# Imported Self_Storage
# Imported Borregaard
# Imported TGS
# Imported AMSC
# Imported NEL
# Imported Hexagon_Composites
# Imported PGS
# Imported Subsea7
# Imported Pexip
# Imported Kid
# Imported Shelf_Drilling
# Imported Norbit
# Imported Sparebanken_More
# Imported Höegh_Autoliners
# Imported Questerre_Energy
# Imported Univid
# Imported Arribatec
# Imported Seadrill
# Imported Sparebank_1_Sorost_Norge
# Imported Prosafe
# Imported Storebrand
# Imported Jinhui_Shipping
# Imported Otello
# Imported ContextVision
# Imported poLight
# Imported Vow
# Imported Otovo
# Imported Wallenius_Wilhelmsen
# Imported KMC_Properties
# Imported Selvaag_Bolig
# Imported Polaris_Media
# Imported Sogn_Sparebank
# Imported IDEX_Biometrics
# Imported GC_Rieber_Shipping

# %%
from borsdata.borsdata_kpi_database_script import kpiDataBase


ord_utd_se_mc = kpiDataBase(66, 'Mid Cap', 'Sverige')
print(ord_utd_se_mc.engine_name)
ord_utd_se_mc.create_database()

ord_utd_dk_mc = kpiDataBase(66, 'Mid Cap', 'Danmark')
print(ord_utd_dk_mc.engine_name)
ord_utd_dk_mc.create_database()

ord_utd_no_mc = kpiDataBase(66, 'Oslo Expand', 'Norge')
print(ord_utd_no_mc.engine_name)
ord_utd_no_mc.create_database()
# Out:
# OrdinarUtdelning_Mid_Cap_Sverige
# Bergman & Beving
# Betsson
# Ependion
# Bioinvent
# Arise Windpower
# Fingerprint Cards
# Eastnine
# BTS Group
# BioGaia
# Cloetta
# Net Insight
# Pricer
# Heba
# CTT Systems
# Clas Ohlson
# I.A.R Systems
# Enea
# Better Collective
# Catena Media
# Duni
# CellaVision
# Scandi Standard
# Beijer Alma
# Öresund
# Byggmax
# Nederman
# Rejlers
# GaroHansa Biopharma
# Synsam
# XANO Industri
# VNV Global
#
# Fagerhult
# K-Fast Holding
# MedCap
# Fasadgruppen
# Norva24
# K2A
# Sivers Semiconductors
# KlaraBo
# SynAct Pharma
# Svolder A
# Gaming Innovation
# Xbrane Biopharma
# TF Bank
# Bulten
# Fastator
# Xvivo Perfusion
# Momentum Group
# Logistea B
# Logistea A
# Catella B
# Engcon
# Karnov
# Mangold
# Resurs Holding
# Ovzon
# Revolutionrace
# Nordic Paper
# Scandic Hotels
# Arctic Paper
# Alligo
# K2A Knaust & Andersson Pref
# Hoist Finance
# Linc
# Lucara Diamond
# Nordic Waterproofing
# Swedish Logistic Property
# AQ Group
# Elanders
# eWork
# Catella A
# Svolder B
# Eolus Vind
# BHG Group
# Probi
# Inwido
# Besqab
# Bactiguard
# Profoto
# Genova Property
# IRLAB Therapeutics
# Tobii Dynavox
# Stendörren Fastigheter
# Gränges
# Dustin Group
# Lime Technologies
# AcadeMedia
# Eltel
# G5 Entertainment
# Concentric
# Balco Group
# Ambea
# Sedana Medical
# Invisio
# Attendo
# CTEK
# Annehem Fastigheter
# Nivika Fastigheter
# Fastighetsbolag Emilshus Pref
# EnQuest
# Humana
# Trianon
# Nordisk Bergteknik
# Camurus
# Bonesupport
# Bonava B
# ITAB Shop Concept
# OEM International
# Alimak
# VBG Group
# Traction
# VEF
# Nobia
# Green Landscaping
# SkiStar
# Cibus Nordic
# Norion Bank
# Fastighetsbolaget Emilshus
# SAS
# Creaspac SPAC
# Calliditas Therapeutics
# Vestum
# BICO Group
# Brinova Fastigheter
# Mildef Group
# NOTE
# MEKO
# Kabe
# Elos Medtech
# Bonava A
# Proact IT
# Tethys Oil
# Rottneros
# Netel Holding
# John Mattson
# KnowIT
# Coor Service Management
# Tobii
# Cavotec
# Africa Oil
# Wästbygg
# RaySearch Laboratories
# FM Mattsson
# Imported Bergman_and_Beving
# Imported Betsson
# Imported Ependion
# Imported Bioinvent
# Imported Arise_Windpower
# Imported Fingerprint_Cards
# Imported Eastnine
# Imported BTS_Group
# Imported BioGaia
# Imported Cloetta
# Imported Net_Insight
# Imported Pricer
# Imported Heba
# Imported CTT_Systems
# Imported Clas_Ohlson
# Imported IAR_Systems
# Imported Enea
# Imported Better_Collective
# Imported Catena_Media
# Imported Duni
# Imported CellaVision
# Imported Scandi_Standard
# Imported Beijer_Alma
# Imported Öresund
# Imported Byggmax
# Imported Nederman
# Imported Rejlers
# Imported Hansa_Biopharma
# Imported Synsam
# Imported XANO_Industri
# Imported VNV_Global
# Imported Garo
# Imported Fagerhult
# Imported K_Fast_Holding
# Imported MedCap
# Imported Fasadgruppen
# Imported Norva24
# Imported K2A
# Imported Sivers_Semiconductors
# Imported KlaraBo
# Imported SynAct_Pharma
# Imported Svolder_A
# Imported Gaming_Innovation
# Imported Xbrane_Biopharma
# Imported TF_Bank
# Imported Bulten
# Imported Fastator
# Imported Xvivo_Perfusion
# Imported Momentum_Group
# Imported Logistea_B
# Imported Logistea_A
# Imported Catella_B
# Imported Engcon
# Imported Karnov
# Imported Mangold
# Imported Resurs_Holding
# Imported Ovzon
# Imported Revolutionrace
# Imported Nordic_Paper
# Imported Scandic_Hotels
# Imported Arctic_Paper
# Imported Alligo
# Imported K2A_Knaust_and_Andersson_Pref
# Imported Hoist_Finance
# Imported Linc
# Imported Lucara_Diamond
# Imported Nordic_Waterproofing
# Imported Swedish_Logistic_Property
# Imported AQ_Group
# Imported Elanders
# Imported eWork
# Imported Catella_A
# Imported Svolder_B
# Imported Eolus_Vind
# Imported BHG_Group
# Imported Probi
# Imported Inwido
# Imported Besqab
# Imported Bactiguard
# Imported Profoto
# Imported Genova_Property
# Imported IRLAB_Therapeutics
# Imported Tobii_Dynavox
# Imported Stendörren_Fastigheter
# Imported Gränges
# Imported Dustin_Group
# Imported Lime_Technologies
# Imported AcadeMedia
# Imported Eltel
# Imported G5_Entertainment
# Imported Concentric
# Imported Balco_Group
# Imported Ambea
# Imported Sedana_Medical
# Imported Invisio
# Imported Attendo
# Imported CTEK
# Imported Annehem_Fastigheter
# Imported Nivika_Fastigheter
# Imported Fastighetsbolag_Emilshus_Pref
# Imported EnQuest
# Imported Humana
# Imported Trianon
# Imported Nordisk_Bergteknik
# Imported Camurus
# Imported Bonesupport
# Imported Bonava_B
# Imported ITAB_Shop_Concept
# Imported OEM_International
# Imported Alimak
# Imported VBG_Group
# Imported Traction
# Imported VEF
# Imported Nobia
# Imported Green_Landscaping
# Imported SkiStar
# Imported Cibus_Nordic
# Imported Norion_Bank
# Imported Fastighetsbolaget_Emilshus
# Imported SAS
# Imported Creaspac_SPAC
# Imported Calliditas_Therapeutics
# Imported Vestum
# Imported BICO_Group
# Imported Brinova_Fastigheter
# Imported Mildef_Group
# Imported NOTE
# Imported MEKO
# Imported Kabe
# Imported Elos_Medtech
# Imported Bonava_A
# Imported Proact_IT
# Imported Tethys_Oil
# Imported Rottneros
# Imported Netel_Holding
# Imported John_Mattson
# Imported KnowIT
# Imported Coor_Service_Management
# Imported Tobii
# Imported Cavotec
# Imported Africa_Oil
# Imported Wästbygg
# Imported RaySearch_Laboratories
# Imported FM_Mattsson
# OrdinarUtdelning_Mid_Cap_Danmark
# SAS
# Bang & Olufsen
# Tivoli
# Flugger
# Per Aarsleff
# Sparekassen Sjaelland-Fyn
# UIE
# AquaporinRTX
# TCM Group
#
# Columbus
# HH International
# Gubra
# Danske Andelskassers
# Vestjysk Bank
# Solar
# Matas
# SP Group
# Brdr. A&O Johansen
# Brdr. Hartmann
# Trifork
# Green Hydrogen
# Nilfisk
# BankNordik
# Gyldendal B
# MT Hojgaard B
# HusCompagniet
# North Media
# cBrain
# Lån og Spar Bank
# NNIT
# Gyldendal A
# Gabriel Holding
# Imported SAS
# Imported Bang_and_Olufsen
# Imported Tivoli
# Imported Flugger
# Imported Per_Aarsleff
# Imported Sparekassen_Sjaelland_Fyn
# Imported UIE
# Imported RTX
# Imported TCM_Group
# Imported Aquaporin
# Imported Columbus
# Imported HH_International
# Imported Gubra
# Imported Danske_Andelskassers
# Imported Vestjysk_Bank
# Imported Solar
# Imported Matas
# Imported SP_Group
# Imported Brdr_AandO_Johansen
# Imported Brdr_Hartmann
# Imported Trifork
# Imported Green_Hydrogen
# Imported Nilfisk
# Imported BankNordik
# Imported Gyldendal_B
# Imported MT_Hojgaard_B
# Imported HusCompagniet
# Imported North_Media
# Imported cBrain
# Imported Lån_og_Spar_Bank
# Imported NNIT
# Imported Gyldendal_A
# Imported Gabriel_Holding
# OrdinarUtdelning_Oslo_Expand_Norge
# Awilco LNG
# EAM Solar
# Norse Atlantic
# Pioneer Property Pref
# Aqua Bio Technology
# Himalaya Shipping
# RomReal
# Philly Shipyard
# Observe Medical
# Seacrest Petroleo Bermuda
# Nordic Mining
# Aquila
# North Energy
# Hunter Group
# Aega
# 5th Planet Games
# Imported Awilco_LNG
# Imported EAM_Solar
# Imported Norse_Atlantic
# Imported Pioneer_Property_Pref
# Imported Aqua_Bio_Technology
# Imported Himalaya_Shipping
# Imported RomReal
# Imported Philly_Shipyard
# Imported Observe_Medical
# Imported Seacrest_Petroleo_Bermuda
# Imported Nordic_Mining
# Imported Aquila
# Imported North_Energy
# Imported Hunter_Group
# Imported Aega
# Imported 5th_Planet_Games

# %%
from borsdata.borsdata_kpi_database_script import kpiDataBase


ord_utd_se_sc = kpiDataBase(66, 'Small Cap', 'Sverige')
print(ord_utd_se_sc.engine_name)
ord_utd_se_sc.create_database()

ord_utd_dk_sc = kpiDataBase(66, 'Small Cap', 'Danmark')
print(ord_utd_dk_sc.engine_name)
ord_utd_dk_sc.create_database()

ord_utd_no_sc = kpiDataBase(66, 'Oslo Growth', 'Norge')
print(ord_utd_no_sc.engine_name)
ord_utd_no_sc.create_database()
# Out:
# OrdinarUtdelning_Small_Cap_Sverige
# Precise BiometricsBE Group
# Active Biotech
# Anoto
# Doro
# Bergs Timber
# Nelly Group
# Bong Ljungdahl
# Björn Borg
#
# Malmbergs Elektriska
# SinterCast
# Formpipe SoftwareNovotek
# NAXS
# PION Group
# Elon
#
# Medivir
# Duroc
# Concejo B
# Lammhults Design
# Strax
# C-RADStockwik Förvaltning
# Pierce Group
# Actic Group
# Ferronordic
#
# Maha Energy
# Projektengagemang
# Isofol Medical
# Orexo
# Wise Group
# Cantargia
# Sleep Cycle
# Ascelia Pharma
# Xspray Pharma
# Acrinova B
# Moberg Pharma
# Christian Berner Tech
# Readly
# Vivesto
# OncopeptidesOrtivus B
# Immunovia
# CoinShares
# Q-Linea
# Prevas
# Midsona A
# IRRAS
# Alligator Bioscience
# Starbreeze A
# Concordia Maritime
#
# Railcare
# Rizzo Group
# Midsona B
# Boule Diagnostics
# Havsfrun Investment
# Vicore Pharma
# Seafire
# Image Systems
# Nilörngruppen
# Softronic
# ProfilGruppen
# Karolinska Development
# Oscar Properties Pref B
# Micro Systemation
# Studsvik
# Saniona
# Abliva
# Senzime
# Mendus
# Starbreeze B
# Arla Plast
# Transtema
# Qliro
# Oscar Properties Pref
# Egetis Therapeutics
# Midway A
# Eniro
# Svedbergs
# Ortivus A
# Midway B
# Acrinova A
# Empir Group
# B3 Consulting
# Sensys Gatso
# TradeDoubler
# Dedicare
# Oscar Properties
# Hanza
# Moment Group
# Infant Bacterial
# Infrea
# Episurf Medical
# Solid Försäkring
# Nanologica
# NGS Group
# Imported BE_Group
# Imported Active_Biotech
# Imported Anoto
# Imported Doro
# Imported Bergs_Timber
# Imported Nelly_Group
# Imported Bong_Ljungdahl
# Imported Björn_Borg
# Imported Precise_Biometrics
# Imported Malmbergs_Elektriska
# Imported SinterCast
# Imported Novotek
# Imported NAXS
# Imported PION_Group
# Imported Elon
# Imported Formpipe_Software
# Imported Medivir
# Imported Duroc
# Imported Concejo_B
# Imported Lammhults_Design
# Imported Strax
# Imported Stockwik_Förvaltning
# Imported Pierce_Group
# Imported Actic_Group
# Imported Ferronordic
# Imported C_RAD
# Imported Maha_Energy
# Imported Projektengagemang
# Imported Isofol_Medical
# Imported Orexo
# Imported Wise_Group
# Imported Cantargia
# Imported Sleep_Cycle
# Imported Ascelia_Pharma
# Imported Xspray_Pharma
# Imported Acrinova_B
# Imported Moberg_Pharma
# Imported Christian_Berner_Tech
# Imported Readly
# Imported Vivesto
# Imported Ortivus_B
# Imported Immunovia
# Imported CoinShares
# Imported Q_Linea
# Imported Prevas
# Imported Midsona_A
# Imported IRRAS
# Imported Alligator_Bioscience
# Imported Starbreeze_A
# Imported Concordia_Maritime
# Imported Oncopeptides
# Imported Railcare
# Imported Rizzo_Group
# Imported Midsona_B
# Imported Boule_Diagnostics
# Imported Havsfrun_Investment
# Imported Vicore_Pharma
# Imported Seafire
# Imported Image_Systems
# Imported Nilörngruppen
# Imported Softronic
# Imported ProfilGruppen
# Imported Karolinska_Development
# Imported Oscar_Properties_Pref_B
# Imported Micro_Systemation
# Imported Studsvik
# Imported Saniona
# Imported Abliva
# Imported Senzime
# Imported Mendus
# Imported Starbreeze_B
# Imported Arla_Plast
# Imported Transtema
# Imported Qliro
# Imported Oscar_Properties_Pref
# Imported Egetis_Therapeutics
# Imported Midway_A
# Imported Eniro
# Imported Svedbergs
# Imported Ortivus_A
# Imported Midway_B
# Imported Acrinova_A
# Imported Empir_Group
# Imported B3_Consulting
# Imported Sensys_Gatso
# Imported TradeDoubler
# Imported Dedicare
# Imported Oscar_Properties
# Imported Hanza
# Imported Moment_Group
# Imported Infant_Bacterial
# Imported Infrea
# Imported Episurf_Medical
# Imported Solid_Försäkring
# Imported Nanologica
# Imported NGS_Group
# OrdinarUtdelning_Small_Cap_Danmark
# Pharma Equity
# Atlantic Petroleum
# BioPorto
# FirstFarms
# Aalborg Boldspilklub
# AGF B
# Roblon
# Copenhagen Capital
# Brd. Klee
# Brondbyernes IF
# Dantax
# SKAKO
# EAC Invest
# Rias
# Orphazyme
# Kreditbanken
# Cemat
# German High Street
# Copenhagen Capital Praef
# Grönlandsbanken
# Penneo
# NewCap Holding
# Nordic Shipholding
# Rovsing
# Lollands Bank
# Harboes Bryggeri
# Scandinavian Investment
# PARKEN Sport
# Skjern Bank
# InterMail
# Hvidbjerg Bank
# Glunz & Jensen
# Silkeborg IF
# Agat Ejendomme
# Fynske Bank
# Mons Bank
# GreenMobility
# Nordfyns Bank
# Prime Office
# Luxor
# Ennogie Solar
# Djurslands Bank
# Fast Ejendom
# NTR Holding
# Park Street
# Scandinavian Brake
# Strategic Investments
# Imported Pharma_Equity
# Imported Atlantic_Petroleum
# Imported BioPorto
# Imported FirstFarms
# Imported Aalborg_Boldspilklub
# Imported AGF_B
# Imported Roblon
# Imported Copenhagen_Capital
# Imported Brd_Klee
# Imported Brondbyernes_IF
# Imported Dantax
# Imported SKAKO
# Imported EAC_Invest
# Imported Rias
# Imported Orphazyme
# Imported Kreditbanken
# Imported Cemat
# Imported German_High_Street
# Imported Copenhagen_Capital_Praef
# Imported Grönlandsbanken
# Imported Penneo
# Imported NewCap_Holding
# Imported Nordic_Shipholding
# Imported Rovsing
# Imported Lollands_Bank
# Imported Harboes_Bryggeri
# Imported Scandinavian_Investment
# Imported PARKEN_Sport
# Imported Skjern_Bank
# Imported InterMail
# Imported Hvidbjerg_Bank
# Imported Glunz_and_Jensen
# Imported Silkeborg_IF
# Imported Agat_Ejendomme
# Imported Fynske_Bank
# Imported Mons_Bank
# Imported GreenMobility
# Imported Nordfyns_Bank
# Imported Prime_Office
# Imported Luxor
# Imported Ennogie_Solar
# Imported Djurslands_Bank
# Imported Fast_Ejendom
# Imported NTR_Holding
# Imported Park_Street
# Imported Scandinavian_Brake
# Imported Strategic_Investments
# OrdinarUtdelning_Oslo_Growth_Norge
# Induct
# BW Epic Kosan
# Grong Sparebank
# Andfjord Salmon
# Arctic Bioscience
# Skandia GreenPower
# ECIT
# Quantafuel
# Instabank
# M Vest Water
# Kyoto GroupCool Company
# Zenith Energy
#
# Ice Fish Farm
# Tysnes Sparebank
# Energeia
# Stainless Tankers
# Shelf Drilling North Sea
# Noram Drilling
# Baltic Sea Properties
# Alternus Energy
# Cyviz
# Inify Laboratories
# Romsdal Sparebank
# EXACT Therapeutics
# Standard Supply
# Huddlestock Fintech
# Questback
# Smartoptics
# Lumi Gruppen
# Zwipe
# CodeLab Capital
# TECO 2030
# Cambi
# Pryme
# Sparebank 68 grader nord
# Nidaros Sparebank
# Gigante Salmon
# Envipco
# Norsk Titanium
# Bergen Carbon
# Nordhealth
# Ocean GeoLoop
# WPU - Waste Plastic Upcycling
# Argeo
# Arctic Fish
# Desert Control
# Golden Energy Offshore
# Benchmark Holdings
# Horisont Energi
# ADS Maritime
# Capsol Technologies
# Proximar Seafood
# Vow Green Metals
# Clean Seas Seafood
# Circa Group
# Lea Bank
# Statt Torsk
# Dolphin Drilling
# Kraft Bank
# Aasen Sparebank
# Deep Value Driller
# Lifecare
# Norsk Solar
# SoftOx Solutions
# Xplora Technologies
# Ayfie
# ReFuels N.V.
# BioFish
# Barramundi
# Hyon
# Ocean Sun
# River Tech
# Nordic Technology
# Aurora Eiendom
# Nordic Aqua Partners
# Awilco Drilling
# Nordic Halibut
# Norcod
# Harmonychain
# Norwegian Block Exchange
# Nordic Unmanned
# Havila Kystruten
# Hav Group
# ININ Group
# CSAM Health
# Pyrum Innovations
# MPC Energy Solutions
# Mintra
# Green Minerals
# Recreate
# Romerike Sparebank
# Black Sea Property
# Akobo Minerals
# Everfuel
# Hynion
# Spotlio
# Lytix Biopharma
# Sunndal Sparebank
# BW Ideol
# Elektroimportoren
# Western Bulk Chartering
# Astrocast
# Icelandic Salmon
# Huddly
# Integrated Wind
# Måsoval
# The Kingfish Company
# Imported Induct
# Imported BW_Epic_Kosan
# Imported Grong_Sparebank
# Imported Andfjord_Salmon
# Imported Arctic_Bioscience
# Imported Skandia_GreenPower
# Imported ECIT
# Imported Quantafuel
# Imported Instabank
# Imported M_Vest_Water
# Imported Cool_Company
# Imported Zenith_Energy
# Imported Kyoto_Group
# Imported Ice_Fish_Farm
# Imported Tysnes_Sparebank
# Imported Energeia
# Imported Stainless_Tankers
# Imported Shelf_Drilling_North_Sea
# Imported Noram_Drilling
# Imported Baltic_Sea_Properties
# Imported Alternus_Energy
# Imported Cyviz
# Imported Inify_Laboratories
# Imported Romsdal_Sparebank
# Imported EXACT_Therapeutics
# Imported Standard_Supply
# Imported Huddlestock_Fintech
# Imported Questback
# Imported Smartoptics
# Imported Lumi_Gruppen
# Imported Zwipe
# Imported CodeLab_Capital
# Imported TECO_2030
# Imported Cambi
# Imported Pryme
# Imported Sparebank_68_grader_nord
# Imported Nidaros_Sparebank
# Imported Gigante_Salmon
# Imported Envipco
# Imported Norsk_Titanium
# Imported Bergen_Carbon
# Imported Nordhealth
# Imported Ocean_GeoLoop
# Imported WPU___Waste_Plastic_Upcycling
# Imported Argeo
# Imported Arctic_Fish
# Imported Desert_Control
# Imported Golden_Energy_Offshore
# Imported Benchmark_Holdings
# Imported Horisont_Energi
# Imported ADS_Maritime
# Imported Capsol_Technologies
# Imported Proximar_Seafood
# Imported Vow_Green_Metals
# Imported Clean_Seas_Seafood
# Imported Circa_Group
# Imported Lea_Bank
# Imported Statt_Torsk
# Imported Dolphin_Drilling
# Imported Kraft_Bank
# Imported Aasen_Sparebank
# Imported Deep_Value_Driller
# Imported Lifecare
# Imported Norsk_Solar
# Imported SoftOx_Solutions
# Imported Xplora_Technologies
# Imported Ayfie
# Imported ReFuels_NV
# Imported BioFish
# Imported Barramundi
# Imported Hyon
# Imported Ocean_Sun
# Imported River_Tech
# Imported Nordic_Technology
# Imported Aurora_Eiendom
# Imported Nordic_Aqua_Partners
# Imported Awilco_Drilling
# Imported Nordic_Halibut
# Imported Norcod
# Imported Harmonychain
# Imported Norwegian_Block_Exchange
# Imported Nordic_Unmanned
# Imported Havila_Kystruten
# Imported Hav_Group
# Imported ININ_Group
# Imported CSAM_Health
# Imported Pyrum_Innovations
# Imported MPC_Energy_Solutions
# Imported Mintra
# Imported Green_Minerals
# Imported Recreate
# Imported Romerike_Sparebank
# Imported Black_Sea_Property
# Imported Akobo_Minerals
# Imported Everfuel
# Imported Hynion
# Imported Spotlio
# Imported Lytix_Biopharma
# Imported Sunndal_Sparebank
# Imported BW_Ideol
# Imported Elektroimportoren
# Imported Western_Bulk_Chartering
# Imported Astrocast
# Imported Icelandic_Salmon
# Imported Huddly
# Imported Integrated_Wind
# Imported Måsoval
# Imported The_Kingfish_Company

# %%
from borsdata.borsdata_price_database_script import priceDataBase

price_lc_se = priceDataBase('Sverige', 'Large Cap', '2010-01-01', '2023-09-01')
print(price_lc_se.engine_name)
price_lc_se.create_database()
# Out:
# prices_Large_Cap_Sverige
# AAK
# Addnode
# Addtech
# ABB
# Bilia
# Biotage
# Bure_Equity
# Corem_Property_A
# Atlas_Copco_A
# Fabege
# Autoliv
# Cint_Group
# Volvo_Car
# Epiroc_B
# Storskogen
# Arjo
# NP3_Fastigheter
# Atrium_Ljungberg
# Beijer_Ref
# Lagercrantz
# Sampo
# Alleima
# Corem_Property_D
# Elekta
# Fenix_Outdoor
# Kinnevik_B
# OX2
# SEB_C
# Getinge
# Sinch
# Instalco
# Corem_Property_B
# AstraZeneca
# Latour
# Truecaller
# Axfood
# Husqvarna_B
# Diös_Fastigheter
# BioArctic
# Fast_Balder
# Billerud
# Samhällsbyggnadsbolag_D
# Intrum
# Holmen_B
# Alfa_Laval
# Hemnet
# Byggfakta
# Boliden
# Catena
# Essity_B
# Avanza_Bank
# Fastpartner_D
# EQT
# Hexagon
# NP3_Fastigheter_Pref
# Hufvudstaden_A
# Electrolux_B
# Munters
# Hexpol
# Sweco_AAssa_Abloy
# Fastpartner_A
#
# Castellum
# HMS_Networks
# Sweco_B
# Mycronic
# Hennes_and_Mauritz
# Indutrade
# Ratos_B
# Pandox
# Essity_A
# Electrolux_Professional_B
# Trelleborg
# Nordea_Bank
# Securitas
# Sdiptech
# Viaplay_A
# Medicover
# Arion_Banki
# Sagax_A
# Traton
# Viaplay_BHexatronic
# Sagax_D
# Millicom
#
# Sdiptech_Pref
# Nyfosa
# Volati_Pref
# Dometic
# Ericsson_B
# Boozt
# Bravida
# Mips
# Ratos_A
# Lundin_Gold
# NIBE_Industrier
# Embracer
# Nolato
# Lundbergföretagen
# Wallenstam
# Troax_Group
# NCAB_Group
# Volvo_B
# International_Petroleum
# Kindred
# Investor_A
# Handelsbanken_B
# Peab
# SSAB_B
# Epiroc_A
# Creades
# Thule
# SEB_A
# Telia_Company
# SSAB_A
# Platzer_Fastigheter
# Loomis
# Skanska
# Orrön_Energy
# Corem_Property_Pref
# Nokia
# Vitrolife
# Volati
# AFRY
# Samhällsbyggnadsbolag_B
# TietoEVRY
# Ericsson_A
# Stillfront
# Modern_Times_Group_A
# Lundin_Mining
# Wihlborgs_Fastigheter
# Sagax_B
# Bufab
# Handelsbanken_A
# AddLife
# Evolution
# SCA_B
# Nordnet
# Husqvarna_A
# SectraLifco
# Atlas_Copco_B
# Tele2_A
#
# Kinnevik_A
# Industrivärden_A
# NCC_A
# JM
# SKF_B
# New_Wave
# Vitec_Software
# NCC_B
# Saab
# Systemair
# Sandvik
# Swedish_Orphan_Biovitrum
# Stora_Enso_R
# Holmen_A
# Industrivärden_C
# Volvo_A
# Lindab
# Electrolux_A
# Tele2_B
# Investor_B
# SKF_A
# Modern_Times_Group_B
# Swedbank
# SCA_A
# Stora_Enso_A
# Fortnox

# %%
from borsdata.borsdata_price_database_script import priceDataBase

price_lc_fi = priceDataBase('Finland', 'Large Cap', '2010-01-01', '2023-09-01')
print(price_lc_fi.engine_name)
price_lc_fi.create_database()

price_mc_fi = priceDataBase('Finland', 'Mid Cap', '2010-01-01', '2023-09-01')
print(price_mc_fi.engine_name)
price_mc_fi.create_database()
# Out:
# prices_Large_Cap_Finland
# Fiskars
# Citycon
# Sanoma
# Huhtamäki
# Kemira
# KONE
# Metsä_Board_B
# Fortum
# Nokian_Renkaat
# Kesko_B
# Elisa
# Stora_Enso_R
# Mandatum
# UPM_Kymmene
# SSAB_B
# Nokia
# TietoEVRY
# Revenio
# Metso
# Vaisala
# Wärtsilä
# Konecranes
# Orion_B
# Nordea_Bank
# Valmet
# Terveystalo
# Outokumpu
# Kojamo
# Telia_Company
# Kesko_A
# Stora_Enso_A
# Qt_Group
# Orion_A
# Cargotec
# Uponor
# Metsä_Board_A
# Neste
# SSAB_A
# Sampo
# prices_Mid_Cap_Finland
# Finnair
# F_Secure
# Evli
# Purmo_Group
# Sitowise_Group
# Lifeline_SPAC
# Puuilo
# Harvia
# Musti_Group
# Anora_Group
# Ponsse_1
# Relais_Group
# YIT_Corporation
# Enento
# Oma_Säästöpankki
# DigiaTokmanni_Group
# Remedy_Entertainment
# Taaleri
#
# Tallink_Grupp
# Caverion
# Gofore
# Rovio
# Oriola_B
# Scanfil
# Verkkokauppacom
# NoHo_PartnersAtria
# Kamux
#
# Pihlajalinna
# Talenom
# Bittium
# Oriola_A
# Aktia_Bank
# Alma_MediaRapala
#
# Marimekko
# Stockmann
# HKScan
# Olvi
# Viking_Line
# Aspo
# Incap
# WithSecure
# Lassila_and_Tikanoja
# CapMan
# Suominen
# eQ_Oyj
# Ålandsbanken_B
# Tecnotree
# Ålandsbanken_A
# Etteplan

# %%
from borsdata.borsdata_kpi_database_script import kpiDataBase

aktier_fi_lc = kpiDataBase(61, 'Large Cap', 'Finland')
print(aktier_fi_lc.engine_name)
aktier_fi_lc.create_database()

aktier_fi_mc = kpiDataBase(61, 'Mid Cap', 'Finland')
print(aktier_fi_mc.engine_name)
aktier_fi_mc.create_database()
# Out:
# AntalAktier_Large_Cap_Finland
# ElisaFiskars
#
# Huhtamäki
# Citycon
# Kesko B
# Cargotec
# Sampo
# Outokumpu
# Fortum
# Wärtsilä
# Kesko A
# Nokia
# UPM-Kymmene
# Mandatum
# Stora Enso AQt Group
#
# Metsä Board B
# Orion A
# Konecranes
# Uponor
# Terveystalo
# Sanoma
# Orion B
# Telia Company
# Metsä Board A
# Nordea Bank
# Neste
# SSAB B
# Stora Enso R
# Vaisala
# TietoEVRY
# Valmet
# SSAB A
# Kojamo
# KONE
# Kemira
# Metso
# Nokian Renkaat
# Revenio
# Imported Fiskars
# Imported Elisa
# Imported Huhtamäki
# Imported Citycon
# Imported Kesko_B
# Imported Cargotec
# Imported Sampo
# Imported Outokumpu
# Imported Fortum
# Imported Wärtsilä
# Imported Kesko_A
# Imported Nokia
# Imported UPM_Kymmene
# Skipped Mandatum
# Imported Qt_Group
# Imported Stora_Enso_A
# Imported Metsä_Board_B
# Imported Orion_A
# Imported Konecranes
# Imported Uponor
# Imported Terveystalo
# Imported Sanoma
# Imported Orion_B
# Imported Telia_Company
# Imported Metsä_Board_A
# Imported Nordea_Bank
# Imported Neste
# Imported SSAB_B
# Imported Stora_Enso_R
# Imported Vaisala
# Imported TietoEVRY
# Imported Valmet
# Imported SSAB_A
# Imported Kojamo
# Imported KONE
# Imported Kemira
# Imported Metso
# Imported Nokian_Renkaat
# Imported Revenio
# AntalAktier_Mid_Cap_Finland
# Oriola B
# Aktia Bank
# Atria
# YIT Corporation
# Finnair
# Pihlajalinna
# Bittium
# Tokmanni GroupPuuilo
#
# Purmo Group
# Tallink Grupp
# Oma Säästöpankki
# Scanfil
# eQ Oyj
# Viking Line
# Stockmann
# Verkkokauppa.com
# Marimekko
# CaverionSuominen
#
# Talenom
# NoHo Partners
# Ponsse 1
# Lifeline SPAC
# F-Secure
# Oriola A
# WithSecure
# Anora Group
# Evli
# Rovio
# Kamux
# Ålandsbanken A
# Alma Media
# Relais Group
# Taaleri
# Tecnotree
# Sitowise Group
# Harvia
# Enento
# Ålandsbanken B
# Digia
# Rapala
# Remedy Entertainment
# HKScan
# Lassila & Tikanoja
# Musti Group
# Gofore
# Olvi
# CapMan
# Incap
# Etteplan
# Aspo
# Imported Oriola_B
# Imported Aktia_Bank
# Imported Atria
# Imported YIT_Corporation
# Imported Finnair
# Imported Pihlajalinna
# Imported Bittium
# Imported Puuilo
# Imported Tokmanni_Group
# Imported Purmo_Group
# Imported Tallink_Grupp
# Imported Oma_Säästöpankki
# Imported Scanfil
# Imported eQ_Oyj
# Imported Viking_Line
# Imported Stockmann
# Imported Verkkokauppacom
# Imported Marimekko
# Imported Suominen
# Imported Caverion
# Imported Talenom
# Imported NoHo_Partners
# Imported Ponsse_1
# Imported Lifeline_SPAC
# Imported F_Secure
# Imported Oriola_A
# Imported WithSecure
# Imported Anora_Group
# Imported Evli
# Imported Rovio
# Imported Kamux
# Imported Ålandsbanken_A
# Imported Alma_Media
# Imported Relais_Group
# Imported Taaleri
# Imported Tecnotree
# Imported Sitowise_Group
# Imported Harvia
# Imported Enento
# Imported Ålandsbanken_B
# Imported Digia
# Imported Rapala
# Imported Remedy_Entertainment
# Imported HKScan
# Imported Lassila_and_Tikanoja
# Imported Musti_Group
# Imported Gofore
# Imported Olvi
# Imported CapMan
# Imported Incap
# Imported Etteplan
# Imported Aspo

# %%
from borsdata.borsdata_price_database_script import priceDataBase


price_lc_no = priceDataBase('Norge', 'Oslo Bors', '2010-01-01', '2023-09-01')
print(price_lc_no.engine_name)
price_lc_no.create_database()

price_lc_dk = priceDataBase('Danmark', 'Large Cap', '2010-01-01', '2023-09-01')
print(price_lc_dk.engine_name)
price_lc_dk.create_database()
# Out:
# prices_Oslo_Bors_Norge
# Aker_BP
# Seadrill
# Storebrand
# Orkla
# DNO
# ABL_Group
# Avance_Gas
# BW_LPG
# DOF_Group
# Equinor
# Gram_Car_Carriers
# SalMar
# BW_Offshore_Limited
# Zalaris
# ContextVision
# NEXT_Biometrics
# SATS
# Tomra_Systems
# Höegh_Autoliners
# XXL
# REC_Silicon
# Vår_Energi
# Archer
# Veidekke
# Elopak
# Rana_Gruber
# AMSC
# NRC_Group
# Aker_Carbon_Capture
# Mowi
# Schibsted_A
# Aker_Solutions
# Volue
# Pexip
# Agilyx
# poLight
# BEWi
# Nordic_Semiconductor
# PetroNor_EandP
# Bien_Sparebank
# Aker_BioMarine
# Aker_Horizons
# Napatech
# PGS
# Gjensidige_Forsikring
# Froy
# Norbit
# Hexagon_PurusSAS
# Norske_Skog
#
# Norwegian_Air_Shuttle
# Wilh_Wilhelmsen_B
# Odfjell_Technology
# Bakkafrost
# Frontline
# Norsk_Hydro
# Yara_International
# Northern_Ocean
# Salmon_Evolution
# HydrogenPro
# Aker
# InterOil_Exploration
# ArcticZymes
# Otello
# Ensurge_Micropower
# Cloudberry_Clean_Energy
# Medistim
# Edda_Wind
# StrongPoint
# Sikri_Group
# TGS
# Subsea7
# Autostore
# Belships
# Tekna_Holding
# Akastor
# TietoEVRY
# Stolt_Nielsen
# Sparebank_1_Nordmore
# Elliptic_Laboratories
# Shelf_Drilling
# Cadeler
# Wallenius_Wilhelmsen
# Holand_Og_Setskog_Sparebank
# Okeanis_Eco_Tankers
# BW_Energy_Limited
# GC_Rieber_Shipping
# Multiconsult
# Eidesvik_Offshore
# Airthings
# Elmera
# Protector
# Kongsberg_Gruppen
# Vistin_Pharma
# Atea
# Arribatec
# Goodtech
# Link_Mobility
# Morrow_Bank
# Aurskog_Sparebank
# 2020_Bulkers
# OKEA
# Zaptec
# AKVA_Group
# Austevoll_Seafood
# Otovo
# Ultimovacs
# SmartCraft
# Adevinta
# Komplett
# MPC_Container_Ships
# Olav_Thon
# Telenor
# Bonheur
# Kahoot!
# Gentian_DiagnosticsGyldendal
# Hafnia_Limited
#
# Klaveness_Combination
# DNB_Bank
# Europris
# Nykode_Therapeutics
# AF_Gruppen
# Northern_Drilling
# Treasure
# ABG_Sundal_Collier
# Totens_Sparebank
# Elkem
# Sparebank_1_Sorost_Norge
# Kid
# Kongsberg_Automotive
# B2Holding
# Skue_Sparebank
# Crayon_Group
# Techstep
# Atlantic_Sapphire
# Sparebank_1_Ostlandet
# BerGenBio
# EQVA
# Sparebank_1_Nord_Norge
# Self_Storage
# PCI_Biotech
# Selvaag_Bolig
# Axactor
# Borr_Drilling
# Nekkar
# Entra
# Endur
# Bouvet
# Webstep
# Scana
# Odfjell_Drilling
# Pareto_Bank
# Oceanteam
# Sparebank_1_Ringerike_Hadeland
# Scatec
# Salmones_Camanchaca
# Vow
# Arendals_Fossekompani
# Saga_Pure
# Sogn_Sparebank
# SD_Standard_ETC
# FLEX_LNG
# Jaeren_Sparebank
# Petrolia
# Grieg_Seafood
# Sparebank_1_Helgeland
# Itera
# Leroy_Seafood
# Sparebanken_Ost
# Melhus_Sparebank
# Odfjell_B
# Carasent
# Sparebank_1_Ostfold_Akershus
# Wilh_Wilhelmsen_A
# Voss_Veksel_Landmandsbank
# KMC_Properties
# Schibsted_B
# Thor_Medical
# Magnora
# Golden_Ocean
# Prosafe
# Siem_Offshore
# Polaris_Media
# Sparebanken_More
# Panoro_Energy
# Byggma
# Bluenord
# Circio
# Reach_Subsea
# Borregaard
# Hexagon_Composites
# Jinhui_Shipping
# Asetek
# Sparebanken_Sor
# Questerre_Energy
# Sparebank_1_SMN
# SeaBird_Exploration
# Hofseth_BioCare
# Univid
# Borgestad
# Sandnes_Sparebank
# SpareBank_1_SR_Bank
# Havila_Shipping
# IDEX_Biometrics
# Sparebanken_Vest
# Q_Free
# Electromagnetic_Geoservices
# Navamedic
# Kitron
# Odfjell_A
# NEL
# Photocure
# Solstad_Offshore
# Gaming_Innovation
# prices_Large_Cap_Danmark
# FLSmidth_and_Co
# Carlsberg_B
# AP_Moller_Maersk_B
# Chr_Hansen
# Danske_Bank
# DSV
# H_Lundbeck_A
# Noble_Corporation
# Coloplast
# ISS
# Novo_Nordisk
# Boozt
# Royal_UNIBREW
# Scandinavian_Tobacco
# Jeudan
# GN_Store_Nord
# Topdanmark
# H_Lundbeck_B
# Pandora
# Jyske_Bank
# Nordea_Bank
# Kobenhavns_Lufthavne
# Tryg
# DFDS
# Netcompany_Group
# Carlsberg_A
# Orsted
# TORM
# Novozymes
# Ringkjobing_Landbobank
# NTG_Nordic_Transport
# Schouw_and_Co
# Bavarian_Nordic
# Össur
# ChemoMetec
# Rockwool_B
# AP_Moller_Maersk_A
# Genmab
# D/S_Norden
# SimCorp
# Rockwool_A
# Alm_Brand
# Sydbank
# Spar_Nord_Bank
# Zealand_Pharma
# Demant
# ALK_Abello
# Ambu
# Vestas_Wind_Systems
# NKT_Holding

# %%
from borsdata.borsdata_price_database_script import priceDataBase


price_mc_no = priceDataBase('Norge', 'Oslo Expand', '2010-01-01', '2023-09-01')
print(price_mc_no.engine_name)
price_mc_no.create_database()

price_mc_dk = priceDataBase('Danmark', 'Mid Cap', '2010-01-01', '2023-09-01')
print(price_mc_dk.engine_name)
price_mc_dk.create_database()
# Out:
# prices_Oslo_Expand_Norge
# Seacrest_Petroleo_Bermuda
# Himalaya_Shipping
# Norse_Atlantic
# Aquila
# Pioneer_Property_Pref
# Nordic_Mining
# Aqua_Bio_Technology
# Aega
# 5th_Planet_Games
# Philly_Shipyard
# Hunter_Group
# North_Energy
# Observe_Medical
# RomReal
# EAM_Solar
# Awilco_LNG
# prices_Mid_Cap_Danmark
# NNIT
# Matas
# Gubra
# Flugger
# Bang_and_Olufsen
# Tivoli
# Per_Aarsleff
# UIE
# Aquaporin
# Sparekassen_Sjaelland_Fyn
# Green_Hydrogen
# HusCompagniet
# Danske_Andelskassers
# Trifork
# BankNordik
# Brdr_AandO_Johansen
# TCM_Group
# cBrain
# Gyldendal_A
# Nilfisk
# Brdr_Hartmann
# MT_Hojgaard_BSP_Group
#
# North_Media
# Solar
# Lån_og_Spar_Bank
# RTX
# Gyldendal_B
# Gabriel_Holding
# Vestjysk_Bank
# Columbus
# HH_International
# SAS

# %%
from borsdata.borsdata_price_database_script import priceDataBase


price_sc_no = priceDataBase('Norge', 'Oslo Growth', '2010-01-01', '2023-09-01')
print(price_sc_no.engine_name)
price_sc_no.create_database()

price_sc_dk = priceDataBase('Danmark', 'Small Cap', '2010-01-01', '2023-09-01')
print(price_sc_dk.engine_name)
price_sc_dk.create_database()
# Out:
# prices_Oslo_Growth_Norge
# Awilco_Drilling
# Romerike_Sparebank
# Aasen_Sparebank
# BW_Epic_Kosan
# Icelandic_Salmon
# Induct
# Ice_Fish_Farm
# Black_Sea_Property
# TECO_2030
# Lifecare
# EverfuelEXACT_Therapeutics
#
# Ayfie
# Zwipe
# CodeLab_Capital
# Grong_Sparebank
# SoftOx_Solutions
# Ocean_GeoLoop
# Stainless_Tankers
# Noram_Drilling
# Hyon
# Standard_Supply
# Kraft_BankCyviz
# ReFuels_NV
# Desert_Control
#
# Nidaros_Sparebank
# Mintra
# Benchmark_Holdings
# CSAM_Health
# Baltic_Sea_Properties
# Bergen_Carbon
# ININ_Group
# Energeia
# Huddlestock_Fintech
# Integrated_Wind
# Dolphin_Drilling
# Romsdal_Sparebank
# Envipco
# Ocean_Sun
# Pyrum_Innovations
# Nordic_Unmanned
# Inify_Laboratories
# Arctic_Fish
# Nordic_Aqua_Partners
# Andfjord_Salmon
# MPC_Energy_Solutions
# Norcod
# Vow_Green_Metals
# Nordic_Technology
# Norwegian_Block_Exchange
# Huddly
# Xplora_Technologies
# BW_Ideol
# Horisont_Energi
# Clean_Seas_Seafood
# Barramundi
# Nordic_Halibut
# Green_Minerals
# Elektroimportoren
# Pryme
# Akobo_Minerals
# The_Kingfish_Company
# ADS_Maritime
# Golden_Energy_Offshore
# Shelf_Drilling_North_Sea
# Lea_Bank
# Proximar_Seafood
# Havila_Kystruten
# Skandia_GreenPower
# Måsoval
# Questback
# Arctic_Bioscience
# Aurora_Eiendom
# Instabank
# Hynion
# Hav_Group
# Norsk_Titanium
# Western_Bulk_Chartering
# Astrocast
# Quantafuel
# Cool_Company
# BioFish
# Lytix_Biopharma
# Capsol_Technologies
# Spotlio
# HarmonychainArgeo
# Recreate
# WPU___Waste_Plastic_Upcycling
#
# Sunndal_Sparebank
# Smartoptics
# Cambi
# Lumi_Gruppen
# Nordhealth
# M_Vest_Water
# ECIT
# Gigante_Salmon
# Statt_Torsk
# Tysnes_Sparebank
# Alternus_Energy
# Zenith_Energy
# Deep_Value_Driller
# Circa_Group
# Kyoto_Group
# Sparebank_68_grader_nord
# Norsk_Solar
# River_Tech
# prices_Small_Cap_Danmark
# Scandinavian_Investment
# Pharma_Equity
# Brondbyernes_IF
# Harboes_Bryggeri
# Roblon
# Penneo
# Brd_Klee
# Kreditbanken
# Copenhagen_Capital_Praef
# GreenMobility
# Strategic_InvestmentsSilkeborg_IF
#
# Grönlandsbanken
# Dantax
# Djurslands_Bank
# InterMail
# Rias
# Orphazyme
# Glunz_and_Jensen
# BioPorto
# Copenhagen_Capital
# Fynske_Bank
# Atlantic_Petroleum
# Agat_Ejendomme
# FirstFarms
# Fast_Ejendom
# German_High_Street
# Ennogie_Solar
# AGF_B
# NTR_Holding
# Hvidbjerg_Bank
# Cemat
# Rovsing
# Lollands_Bank
# Aalborg_Boldspilklub
# Mons_Bank
# Nordic_ShipholdingScandinavian_Brake
#
# PARKEN_Sport
# Skjern_Bank
# EAC_Invest
# Luxor
# Nordfyns_Bank
# SKAKO
# Park_Street
# NewCap_Holding
# Prime_Office

# %%
from borsdata.borsdata_price_database_script import priceDataBase


price_sc_se = priceDataBase('Sverige', 'Small Cap', '2010-01-01', '2023-09-01')
print(price_sc_se.engine_name)
price_sc_se.create_database()

price_mc_se = priceDataBase('Sverige', 'Mid Cap', '2010-01-01', '2023-09-01')
print(price_mc_se.engine_name)
price_mc_se.create_database()
# Out:
# prices_Small_Cap_Sverige
# Concordia_Maritime
# Nelly_Group
# Bong_Ljungdahl
# BE_Group
# Björn_Borg
# Bergs_Timber
# Active_Biotech
# Anoto
# Concejo_B
# Vivesto
# Elon
# Ortivus_B
# Midway_B
# NAXS
# Qliro
# Orexo
# Eniro
# Precise_Biometrics
# Lammhults_Design
# Doro
# Solid_Försäkring
# CoinShares
# Arla_Plast
# Readly
# Image_Systems
# Studsvik
# Q_Linea
# Sleep_Cycle
# Acrinova_A
# Micro_Systemation
# Ferronordic
# Oscar_Properties_Pref
# Vicore_Pharma
# Pierce_Group
# Oncopeptides
# Alligator_Bioscience
# Moberg_Pharma
# Saniona
# Ascelia_Pharma
# Acrinova_B
# ProfilGruppen
# Midsona_B
# Seafire
# Midway_A
# Stockwik_Förvaltning
# Formpipe_Software
# Episurf_Medical
# Havsfrun_Investment
# Novotek
# Karolinska_Development
# Starbreeze_B
# Malmbergs_Elektriska
# Immunovia
# Oscar_Properties_Pref_B
# Transtema
# Softronic
# Oscar_Properties
# Empir_Group
# Midsona_A
# Nanologica
# Christian_Berner_Tech
# Infrea
# C_RAD
# IRRAS
# ProjektengagemangStarbreeze_A
# Actic_Group
#
# Hanza
# Prevas
# SinterCast
# Moment_Group
# Maha_Energy
# Xspray_Pharma
# PION_Group
# TradeDoubler
# Rizzo_Group
# Boule_Diagnostics
# Isofol_Medical
# Infant_Bacterial
# NGS_Group
# B3_Consulting
# Senzime
# Dedicare
# Railcare
# Sensys_Gatso
# Egetis_Therapeutics
# Svedbergs
# Nilörngruppen
# Cantargia
# Strax
# Abliva
# Mendus
# Ortivus_A
# Duroc
# Medivir
# Wise_Group
# prices_Mid_Cap_Sverige
# BioGaia
# Betsson
# Bergman_and_Beving
# Brinova_Fastigheter
# Netel_Holding
# BTS_Group
# Elanders
# Eastnine
# Net_Insight
# Arise_Windpower
# Ependion
# Norva24
# Traction
# Nordisk_Bergteknik
# Clas_Ohlson
# Synsam
# Wästbygg
# Nobia
# Swedish_Logistic_Property
# OEM_International
# Bioinvent
# Engcon
# MEKO
# Logistea_B
# Annehem_Fastigheter
# Proact_IT
# CTEK
# Fastighetsbolaget_Emilshus
# Heba
# Byggmax
# EnQuest
# KlaraBo
# FM_Mattsson
# Momentum_Group
# Lime_Technologies
# Rejlers
# KarnovFastighetsbolag_Emilshus_Pref
# Calliditas_Therapeutics
#
# Nivika_Fastigheter
# Duni
# Profoto
# RaySearch_Laboratories
# CTT_Systems
# Revolutionrace
# Linc
# Creaspac_SPAC
# Gaming_Innovation
# Tobii_Dynavox
# Öresund
# Mildef_Group
# BHG_Group
# Cibus_Nordic
# IAR_Systems
# Ovzon
# Green_Landscaping
# Logistea_A
# Cavotec
# Genova_Property
# Nordic_Waterproofing
# Nordic_Paper
# Bonesupport
# BICO_Group
# IRLAB_Therapeutics
# Alimak
# Rottneros
# K2A_Knaust_and_Andersson_Pref
# K_Fast_Holding
# Better_Collective
# Beijer_Alma
# Bactiguard
# Attendo
# Ambea
# eWork
# K2A
# Invisio
# Nederman
# Fasadgruppen
# NOTE
# Balco_Group
# John_Mattson
# VBG_Group
# Sedana_Medical
# CellaVision
# Hansa_Biopharma
# Bonava_B
# Inwido
# Trianon
# Africa_OilVEF
# VNV_Global
# Alligo
# Bonava_A
# Fingerprint_Cards
# Xbrane_Biopharma
#
# Humana
# Hoist_Finance
# Kabe
# Catena_Media
# Gränges
# Resurs_Holding
# Svolder_B
# SynAct_Pharma
# Coor_Service_Management
# Eolus_Vind
# Svolder_A
# Cloetta
# SkiStar
# Lucara_Diamond
# Enea
# ConcentricSivers_Semiconductors
# Catella_B
#
# Catella_A
# Vestum
# Garo
# Besqab
# ITAB_Shop_Concept
# Probi
# AcadeMedia
# MedCap
# AQ_Group
# Dustin_Group
# Xvivo_Perfusion
# Fastator
# Eltel
# Bulten
# Scandic_Hotels
# SAS
# Norion_Bank
# TF_Bank
# XANO_Industri
# Tethys_Oil
# Elos_Medtech
# Tobii
# Fagerhult
# Camurus
# KnowIT
# Mangold
# Arctic_Paper
# Scandi_Standard
# G5_Entertainment
# Pricer
# Stendörren_Fastigheter
